# %% [markdown]
# # General Information
# This python code using flight data to obtain constrain, cost function and pairings.
# <br>
# Using Paper:  _**Robust Crew Pairing for Managing Extra Flights**_
# <br>
# Bases are; <br \>
#     1 - Ankara <br \>
# <br>
# Constraints are;
#
# |      Name      |        Description            |    Value     |
# |----------------|-------------------------------|--------------|
# | $t^{min}_{s}$  |  Minimum Sit Time             |  $60$  min   |
# | $t^{max}_{s}$  |  Maximum Sit Time             |  $240$ min   |
# | $t^{min}_{r}$  |  Minimum Rest Time            |  $600$ min   |
# | $t^{max}_{r}$  |  Maximum Rest Time            |  $980$ min   |
# | $N_{p}      $  |  Total Day in one Pairing     |  $4$ Day     |
# | $N_{d}      $  |  Number of flight in one Duty |  $3$ Flight  |
# | $T_{d}      $  |  Max Total (1- Duty) Time     |  $7$ Hour    |
# | $T_{f}      $  |  Max Total (1- Duty) Time     |  $5$ Hour    |
#
# Earnings are;

# %% [markdown]
# # Python Data Prepering
# ## Import and From Libraries

# %%
import pandas as pd           # Importing Pandas Library
import numpy as np            # Importing Numpy Library
from datetime import datetime # Importing Date Time to allow us doing math between two time
import scipy.io as sio        # Importing Sio to allow saving our mat files.

# %% [markdown]
# ## Reading CSV Flight Data

# %%
DataPath   = r'Data File/FlightDataSet38.csv'             # Definition of Data Path
FlightData = pd.read_csv(DataPath, sep=',', dtype=str)  # Flight Data reading from csv file
FlightData.head(5)                                      # Visualize first 5 row
# Out:
#   Flight ID Dept. L. Arr. L. Dept. T.   Arr. T.
# 0         1      IST     ANK     07:00    08:00
# 1         2      IST     IZM     06:00    07:00
# 2         3      IZM     ANK     10:05    11:20
# 3         4      IST     ANT     08:25    09:40
# 4         5      IZM     ANK     19:20    20:40

# %% [markdown]
# ## Chaning Data Type to Array and Obtaining Links

# %%
FlightData = FlightData.values # Changing Data Type to Array

# %%
# Saving Arrival and Departures
Arrival = FlightData[:,2]
Departure = FlightData[:,1]
Dep_Flight_Ank = np.array(np.where(Departure == 'ANT'))
Arr_Flight_Ank = np.array(np.where(Arrival =='ANT'))
foo = []
for i in range(Dep_Flight_Ank.shape[1]):
    for j in range(Arr_Flight_Ank.shape[1]):
        foo.append((Dep_Flight_Ank[0][i],Arr_Flight_Ank[0][j]))

# %%
# Obtaining Links with for loop
Flight_links = []
for i in range(len(FlightData)):
    for j in range(len(FlightData)):
        if FlightData[i][2] == FlightData[j][1]:
            Flight_links.append((FlightData[i,1:5], FlightData[j,1:5], 'Flight IDs :', i+1,j+1))

# %%
Flight_links
# Out:
# [(array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   1,
#   29),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   1,
#   30),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   31),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   32),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   33),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   34),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   35),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   36),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   37),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   38),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   2,
#   3),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   2,
#   5),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   6),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   12),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   16),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   19),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   2,
#   22),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   24),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   3,
#   29),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   3,
#   30),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   31),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   32),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   33),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   34),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   35),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   36),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   37),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   38),
#  (array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   'Flight IDs :',
#   4,
#   7),
#  (array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   'Flight IDs :',
#   4,
#   11),
#  (array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   'Flight IDs :',
#   4,
#   18),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   5,
#   29),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   5,
#   30),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   31),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   32),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   33),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   34),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   35),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   36),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   37),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   38),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   1),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   2),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   6,
#   4),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   6,
#   8),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   9),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   10),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   13),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   6,
#   14),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   15),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   17),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   20),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   21),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   23),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   25),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   26),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   27),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   6,
#   28),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   1),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   2),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   7,
#   4),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   7,
#   8),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   9),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   10),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   13),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   7,
#   14),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   15),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   17),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   20),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   21),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   23),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   25),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   26),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   27),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   7,
#   28),
#  (array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   'Flight IDs :',
#   8,
#   7),
#  (array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   'Flight IDs :',
#   8,
#   11),
#  (array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   'Flight IDs :',
#   8,
#   18),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   9,
#   3),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   9,
#   5),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   6),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   12),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   16),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   19),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   9,
#   22),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   24),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   10,
#   3),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   10,
#   5),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   6),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   12),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   16),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   19),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   10,
#   22),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   24),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   1),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   2),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   11,
#   4),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   11,
#   8),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   9),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   10),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   13),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   11,
#   14),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   15),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   17),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   20),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   21),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   23),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   25),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   26),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   27),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   11,
#   28),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   1),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   2),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   12,
#   4),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   12,
#   8),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   9),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   10),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   13),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   12,
#   14),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   15),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   17),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   20),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   21),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   23),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   25),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   26),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   27),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   12,
#   28),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   13,
#   29),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   13,
#   30),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   31),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   32),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   33),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   34),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   35),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   36),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   37),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   38),
#  (array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   'Flight IDs :',
#   14,
#   7),
#  (array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   'Flight IDs :',
#   14,
#   11),
#  (array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   'Flight IDs :',
#   14,
#   18),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   15,
#   3),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   15,
#   5),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   15,
#   6),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   15,
#   12),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   15,
#   16),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   15,
#   19),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   15,
#   22),
#  (array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   15,
#   24),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   1),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   2),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   16,
#   4),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   16,
#   8),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   9),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   10),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   13),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   16,
#   14),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   15),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   17),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   20),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   21),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   23),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   25),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   26),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   27),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   16,
#   28),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   17,
#   29),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   17,
#   30),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   31),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   32),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   33),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   34),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   35),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   36),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   37),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   38),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   1),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   2),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   18,
#   4),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   18,
#   8),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   9),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   10),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   13),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   18,
#   14),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   15),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   17),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   20),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   21),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   23),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   25),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   26),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   27),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   18,
#   28),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   1),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   2),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   19,
#   4),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   19,
#   8),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   9),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   10),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   13),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   19,
#   14),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   15),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   17),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   20),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   21),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   23),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   25),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   26),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   27),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   19,
#   28),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   20,
#   29),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   20,
#   30),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   31),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   32),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   33),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   34),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   35),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   36),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   37),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   38),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   21,
#   3),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   21,
#   5),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   6),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   12),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   16),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   19),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   21,
#   22),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   24),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   1),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   2),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   22,
#   4),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   22,
#   8),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   9),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   10),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   13),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   22,
#   14),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   15),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   17),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   20),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   21),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   23),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   25),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   26),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   27),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   22,
#   28),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   23,
#   29),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   23,
#   30),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   31),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   32),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   33),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   34),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   35),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   36),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   37),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   38),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   1),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   2),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   24,
#   4),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   24,
#   8),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   9),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   10),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   13),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   24,
#   14),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   15),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   17),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   20),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   21),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   23),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   25),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   26),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   27),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   24,
#   28),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   25,
#   3),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   25,
#   5),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   6),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   12),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   16),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   19),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   25,
#   22),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   24),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   26,
#   29),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   26,
#   30),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   31),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   32),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   33),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   34),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   35),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   36),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   37),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   38),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   27,
#   29),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   27,
#   30),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   31),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   32),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   33),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   34),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   35),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   36),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   37),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   38),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   28,
#   29),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   28,
#   30),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   31),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   32),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   33),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   34),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   35),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   36),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   37),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   38),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   29,
#   3),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   29,
#   5),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   6),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   12),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   16),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   19),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   29,
#   22),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   24),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   30,
#   3),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   30,
#   5),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   6),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   12),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   16),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   19),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   30,
#   22),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   24),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   1),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   2),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   31,
#   4),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   31,
#   8),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   9),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   10),
# ...
#   'Flight IDs :',
#   32,
#   15),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   17),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   20),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   21),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   23),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   25),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   26),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   27),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   32,
#   28),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   1),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   2),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   33,
#   4),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   33,
#   8),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   9),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   10),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   13),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   33,
#   14),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   15),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   17),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   20),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   21),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   23),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   25),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   26),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   27),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   33,
#   28),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   1),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   2),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   34,
#   4),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   34,
#   8),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   9),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   10),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   13),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   34,
#   14),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   15),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   17),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   20),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   21),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   23),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   25),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   26),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   27),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   34,
#   28),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   1),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   2),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   35,
#   4),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   35,
#   8),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   9),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   10),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   13),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   35,
#   14),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   15),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   17),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   20),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   21),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   23),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   25),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   26),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   27),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   35,
#   28),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   1),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   2),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   36,
#   4),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   36,
#   8),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   9),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   10),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   13),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   36,
#   14),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   15),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   17),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   20),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   21),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   23),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   25),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   26),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   27),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   36,
#   28),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   1),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   2),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   37,
#   4),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   37,
#   8),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   9),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   10),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   13),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   37,
#   14),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   15),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   17),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   20),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   21),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   23),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   25),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   26),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   27),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   37,
#   28),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   1),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   2),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   38,
#   4),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   38,
#   8),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   9),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   10),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   13),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   38,
#   14),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   15),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   17),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   20),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   21),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   23),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   25),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   26),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   27),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   38,
#   28)]

# %% [markdown]
# ## Using Sit Time Constraint to Eliminate Unnecessary Links
# Minimum Sitting Time is 60 min. <br \>
# Maximum Sitting Time is 240 min.  <br \>
# According to these constraints we can eliminate links with using for loops

# %%
# New Links with Constarints
Cons_Flight_links = []
Time_Format = '%H:%M'
for i in range(len(Flight_links)):
    # Looking Sit Time
    if (datetime.strptime(Flight_links[i][1][2], Time_Format) - datetime.strptime(Flight_links[i][0][3], Time_Format)).seconds/60 > 60 and (datetime.strptime(Flight_links[i][1][2], Time_Format) - datetime.strptime(Flight_links[i][0][3], Time_Format)).seconds/60 < 240:
        Cons_Flight_links.append(Flight_links[i])
    # Looking Rest Time
    elif (datetime.strptime(Flight_links[i][1][2], Time_Format) - datetime.strptime(Flight_links[i][0][3], Time_Format)).seconds/60 > 600 and (datetime.strptime(Flight_links[i][1][2], Time_Format) - datetime.strptime(Flight_links[i][0][3], Time_Format)).seconds/60 < 980:
        Cons_Flight_links.append(Flight_links[i])

# %%
Cons_Flight_links
# Out:
# [(array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   32),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   36),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   37),
#  (array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   1,
#   38),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   2,
#   3),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   2,
#   5),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   6),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   2,
#   22),
#  (array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   2,
#   24),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   33),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   35),
#  (array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   3,
#   38),
#  (array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   'Flight IDs :',
#   4,
#   7),
#  (array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   'Flight IDs :',
#   4,
#   18),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   5,
#   29),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   31),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   32),
#  (array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   5,
#   38),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   15),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   17),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   6,
#   27),
#  (array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   6,
#   28),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   7,
#   8),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   7,
#   20),
#  (array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   7,
#   28),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   16),
#  (array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   9,
#   24),
#  (array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   10,
#   19),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   1),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   2),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   11,
#   4),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   9),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   25),
#  (array(['ANT', 'IST', '16:50', '18:05'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   11,
#   27),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   12,
#   8),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   12,
#   20),
#  (array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   12,
#   28),
#  (array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   13,
#   33),
#  (array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   array(['ANT', 'IST', '11:00', '12:10'], dtype=object),
#   'Flight IDs :',
#   14,
#   7),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   2),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   21),
#  (array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   16,
#   23),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   17,
#   30),
#  (array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   17,
#   34),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   18,
#   8),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   9),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   10),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   13),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   15),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   18,
#   17),
#  (array(['ANT', 'IST', '21:15', '22:30'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   18,
#   28),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   1),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   2),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANT', '19:00', '20:15'], dtype=object),
#   'Flight IDs :',
#   19,
#   14),
#  (array(['IZM', 'IST', '15:00', '16:00'], dtype=object),
#   array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   'Flight IDs :',
#   19,
#   26),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   20,
#   29),
#  (array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   20,
#   31),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   21,
#   3),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   21,
#   5),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   21,
#   6),
#  (array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   21,
#   22),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   1),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   22,
#   4),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   9),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   10),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   13),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   22,
#   27),
#  (array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   22,
#   28),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   23,
#   29),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   31),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   36),
#  (array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   23,
#   37),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   24,
#   8),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   10),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   13),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   15),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   17),
#  (array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   24,
#   20),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   25,
#   3),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   6),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   12),
#  (array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   25,
#   16),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   'Flight IDs :',
#   26,
#   29),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   31),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   32),
#  (array(['IST', 'ANK', '19:00', '20:00'], dtype=object),
#   array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   26,
#   38),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   32),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   33),
#  (array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   27,
#   35),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   'Flight IDs :',
#   28,
#   30),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   32),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   33),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   34),
#  (array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   28,
#   35),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'ANK', '19:20', '20:40'], dtype=object),
#   'Flight IDs :',
#   29,
#   5),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   12),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   16),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '19:20', '20:20'], dtype=object),
#   'Flight IDs :',
#   29,
#   22),
#  (array(['ANK', 'IZM', '07:45', '09:05'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   29,
#   24),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'ANK', '10:05', '11:20'], dtype=object),
#   'Flight IDs :',
#   30,
#   3),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   6),
#  (array(['ANK', 'IZM', '17:00', '18:20'], dtype=object),
#   array(['IZM', 'IST', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   30,
#   24),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   10),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   13),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   25),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANK', '22:00', '23:00'], dtype=object),
#   'Flight IDs :',
#   31,
#   27),
#  (array(['ANK', 'IST', '08:00', '09:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   31,
#   28),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   32,
#   8),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   32,
#   20),
#  (array(['ANK', 'IST', '11:00', '12:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   32,
#   28),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   1),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   2),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   21),
#  (array(['ANK', 'IST', '14:00', '15:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   33,
#   23),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANK', '07:00', '08:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   1),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   2),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   34,
#   4),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   9),
#  (array(['ANK', 'IST', '17:00', '18:00'], dtype=object),
#   array(['IST', 'IZM', '20:00', '21:00'], dtype=object),
#   'Flight IDs :',
#   34,
#   25),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '06:00', '07:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   2),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'IZM', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   21),
#  (array(['ANK', 'IST', '13:00', '14:00'], dtype=object),
#   array(['IST', 'ANK', '17:00', '18:00'], dtype=object),
#   'Flight IDs :',
#   35,
#   23),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   36,
#   4),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   9),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   10),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   13),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   15),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   36,
#   17),
#  (array(['ANK', 'IST', '21:00', '22:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   36,
#   28),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANT', '08:25', '09:40'], dtype=object),
#   'Flight IDs :',
#   37,
#   4),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '09:00', '10:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   9),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   10),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   13),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   15),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   37,
#   17),
#  (array(['ANK', 'IST', '20:00', '21:00'], dtype=object),
#   array(['IST', 'ANK', '23:45', '00:45'], dtype=object),
#   'Flight IDs :',
#   37,
#   28),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANT', '14:25', '15:50'], dtype=object),
#   'Flight IDs :',
#   38,
#   8),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   10),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '11:00', '12:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   13),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'IZM', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   15),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '13:00', '14:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   17),
#  (array(['ANK', 'IST', '22:00', '23:00'], dtype=object),
#   array(['IST', 'ANK', '15:00', '16:00'], dtype=object),
#   'Flight IDs :',
#   38,
#   20)]

# %% [markdown]
# ## Using Iterations to obtain Links with Different Initial Flights
# ##### This code is obtained from Ozgun's projects directly just changing variables name.

# %%
# Allocation for iterations
iterations_start = np.zeros(len(Cons_Flight_links), dtype=np.uint32)
iterations_end = np.zeros(len(Cons_Flight_links), dtype=np.uint32)
#-----------------------------------------------------------------#  
# Iteration Process
for i in range(len(Cons_Flight_links)):
    iterations_start[i] = Cons_Flight_links[i][3]
    iterations_end[i] = Cons_Flight_links[i][4]
#-----------------------------------------------------------------#  
# Get rid of unnecessary initial flgihts
iterations_start_unique = np.unique(iterations_start)
unique, counts = np.unique(iterations_start, return_counts=True)
occurences =  dict(zip(unique, counts))
#-----------------------------------------------------------------#  
# Total with 16 bit unit
total = np.zeros(len(occurences)+1, dtype=np.uint16)
total[0] = 0
#-----------------------------------------------------------------#  
# Obtainin Arrival Location for One Departure
for i in range(len(occurences)):
    total[i+1] = total[i] + counts[i]
#-----------------------------------------------------------------#    
# Allocation for Multiple 1- Links    
MLinks_Flight = {}
for i in range(len(iterations_start_unique)):
    Un_Iter = iterations_start_unique[i]
    Val_Iter = iterations_end[total[i]:total[i+1]]
    Val_Iter = set(Val_Iter)
    MLinks_Flight[Un_Iter] = Val_Iter

# %%
MLinks_Flight
# Out:
# {1: {32, 36, 37, 38},
#  2: {3, 5, 6, 22, 24},
#  3: {33, 35, 38},
#  4: {7, 18},
#  5: {29, 31, 32, 38},
#  6: {15, 17, 27, 28},
#  7: {8, 20, 28},
#  9: {16, 24},
#  10: {19},
#  11: {1, 2, 4, 9, 25, 27},
#  12: {8, 20, 28},
#  13: {33},
#  14: {7},
#  16: {2, 21, 23},
#  17: {30, 34},
#  18: {8, 9, 10, 13, 15, 17, 28},
#  19: {1, 2, 14, 26},
#  20: {29, 31},
#  21: {3, 5, 6, 22},
#  22: {1, 4, 9, 10, 13, 27, 28},
#  23: {29, 31, 36, 37},
#  24: {8, 10, 13, 15, 17, 20},
#  25: {3, 6, 12, 16},
#  26: {29, 31, 32, 38},
#  27: {32, 33, 35},
#  28: {30, 32, 33, 34, 35},
#  29: {5, 12, 16, 22, 24},
#  30: {3, 6, 24},
#  31: {10, 13, 25, 27, 28},
#  32: {8, 20, 28},
#  33: {1, 2, 21, 23},
#  34: {1, 2, 4, 9, 25},
#  35: {2, 21, 23},
#  36: {4, 9, 10, 13, 15, 17, 28},
#  37: {4, 9, 10, 13, 15, 17, 28},
#  38: {8, 10, 13, 15, 17, 20}}

# %% [markdown]
# ## Obtaining Pairs with using "Depth Search"

# %%
# Definition of Depth Search
def dfs_paths(graph, start, goal):
    stack = [(start, [start])]
    while stack:
        (vertex, path) = stack.pop()
        if vertex in MLinks_Flight:
            for next in graph[vertex] - set(path):
                if next == goal:
                    yield path + [next]
                else:
                    stack.append((next, path + [next]))
                    if len(stack) == 4:
                        exit()
        else:
            pass

# %%
# Obtaining Pairs starting with ANT, ending with ANT
pairing = []
for i in range(len(foo)):
    pairing.append((dfs_paths(MLinks_Flight, foo[i][0], foo[i][1])))

# %%
for i in range(len(pairing)):
    pairing[i] = list(pairing[i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-d4101e4f2f72> in <module>()
#       1 for i in range(len(pairing)):
# ----> 2     pairing[i] = list(pairing[i])
#
# <ipython-input-34-7d2384f7398b> in dfs_paths(graph, start, goal)
#       6         if vertex in MLinks_Flight:
#       7             for next in graph[vertex] - set(path):
# ----> 8                 if next == goal:
#       9                     yield path + [next]
#      10                 else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Eliminate Unnecessary Pairings
# 1- Max number of flight is $3$. <br \>
# 2- Max number of duty in pairings $4$. <br \>
# Thus, maximum number of flight in pairins must be $12$

# %%
# First Elimination with maximum flight in pairs
Ele1_Pairs_Ist = []
for i in range(len(Pairs_IST)):
    if len(Pairs_IST[i]) < 12:
        Ele1_Pairs_Ist.append(Pairs_IST[i])

# %%
# Second Elimination with duties
#'Minmum Number of duty is 2 So if we have single flight in duty so we eliminate these pairings '
#Ele2_Pairs_Ist = []
#for i in range(len(Ele1_Pairs_Ist)):
#    if (datetime.strptime(FlightData[Ele1_Pairs_Ist[0][1]-1][3], Time_Format) - (datetime.strptime(FlightData[Ele1_Pairs_Ist[0][0]-1][4], Time_Format))).seconds/60 < 540:
#        Ele2_Pairs_Ist.append(Ele1_Pairs_Ist[i])

# %% [markdown]
# ## Cost Calculation
# 1- We need total flight time in a pairings <br>
# 2- For one pairins 1 hour in flight is $500$ TL. <br>
# 3- For one pairings if minutes between flight is less than 2 hour than its cost is $200$ TL. <br>

# %% [markdown]
# ## Obtaining Matrix
# Obtaining A, B, C Matrices with our pairings and flights. <br \>
# A Matrix $\Rightarrow$ FlightData x Pairing List <br \>
# B Matrix $\Rightarrow$ FlightData x 1 with ones  <br \>
# C Matrix $\Rightarrow$ 1 x Pairing List with random numbers between range $5$ and $50$  <br \>

# %%
# A Matrix
Amat = np.zeros((len(FlightData),len(Ele1_Pairs_Ist)), dtype=np.int16)
for i in range(len(Ele1_Pairs_Ist)):
    for j in range(len(Ele1_Pairs_Ist[i])):
        Save_Indices = Ele1_Pairs_Ist[i][j]-1
        Amat[Save_Indices][i] = 1
Amat = Amat[~(Amat==0).all(1)]
#-----------------------------------------------------------------#  
# B Matrix
Bmat = np.ones((Amat.shape[0],1), dtype=np.int16)
#-----------------------------------------------------------------#
# C Matrix
Cmat = np.zeros(Amat.shape[1], dtype=np.int16)
for i in range(len(Cmat)):
    Cmat[i] = np.random.uniform(5, 25)
#-----------------------------------------------------------------#
# Saving Matrices as Mat File
sio.savemat('Cmat.mat', {'Cmatrix': Cmat})
sio.savemat('Amat.mat', {'Amatrix': Amat})
sio.savemat('Bmat.mat', {'Bmatrix': Bmat})
